# %%
# Data Manipulation
import pandas as pd # for data manipulation
import numpy as np # for data manipulation

# Training utils
import utils_xgboost

# Optuna
import optuna
import pickle

# Tiempo
import datetime as dt
from dateutil.relativedelta import relativedelta, MO

# Modelos
from sklearn.linear_model import LinearRegression # for building a linear regression model
from sklearn.svm import SVR # for building SVR model
from sklearn.preprocessing import MinMaxScaler
from sklearn.multioutput import MultiOutputRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split

# Metricas
from sklearn.metrics import mean_absolute_error #MAE
from sklearn.metrics import mean_absolute_percentage_error #MAPE
from sklearn.metrics import mean_squared_error #MSE, para RMSE: squared = False

# Visualizations
import plotly.graph_objects as go # for data visualization
import plotly.express as px # for data visualization
import matplotlib.pyplot as plt

# Advertencias
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Fer\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# # VALIDACION

# %%
datos = pd.read_csv('datos/230127_train_ESTACIONES.csv', parse_dates = ['FECHAHORA'])
validacion = pd.read_csv('datos/230127_test_ESTACIONES.csv', parse_dates = ['FECHAHORA'])

# %%
e1 = validacion[validacion['ESTACION'] == 1]

e1.FECHAHORA.min()
# Out:
# Timestamp('2021-03-30 13:05:00')

# %%
# %%time

predicciones = {}
metricas = {}

for i in range(1, 11):
    
    estacion = i

    variables = ["ANHO", 'DIA', 'MES', 'HORA', 'MINUTO', 'MP1', 'MP2_5', 'MP10', 
                 'TEMPERATURA', 'HUMEDAD', 'PRESION', 'TEMPERATURA_PRONOSTICO', 
                 'HUMEDAD_PRONOSTICO', 'PRESION_PRONOSTICO', 'DIA_SEM', 'TRAFICO' , 'AQI_MP10', 'AQI_MP2_5']

    dependent = ['AQI_MP2_5']

    number_of_features = len(variables)

    training_days = 2 
    forecast_days = 1 
    samples_per_day = 288
    step = 288/4

    # Creamos una variable que nos diga con cuantos meses de entrenamiento queremos contar para el X_train
    train_months = relativedelta(months = 12)
    test_months = relativedelta(months = 2, days = 20)

    input_samples = int(samples_per_day * training_days) # cantidad de muestras en 7 dias
    output_samples = int(samples_per_day * forecast_days) # cantidad de muestras en 1 dia
    train_test_samples = int(input_samples + output_samples) # cantidad de datos para el train_test



    X_train, y_train, X_test, y_test = utils_xgboost.get_everything(datos, 
                                                                    estacion,
                                                                    train_months, 
                                                                    variables, 
                                                                    dependent, 
                                                                    train_test_samples, 
                                                                    input_samples, 
                                                                    output_samples, 
                                                                    number_of_features,
                                                                    step)

    X_train_val, y_train_val, X_test_val, y_test_val = utils_xgboost.get_everything(validacion, 
                                                                    estacion,
                                                                    test_months, 
                                                                    variables, 
                                                                    dependent, 
                                                                    train_test_samples, 
                                                                    input_samples, 
                                                                    output_samples, 
                                                                    number_of_features,
                                                                    step)

    params = {'max_depth': 5,
        'learning_rate': 0.03501312736977673,
        'n_estimators': 78,
        'min_child_weight': 8,
        'gamma': 0.00590507825523195,
        'subsample': 0.577093202211148,
        'colsample_bytree': 0.7936061869990182} 

    xgb_model = xgb.XGBRegressor(** params)

    trained_xgb_model = MultiOutputRegressor(xgb_model).fit(X_train , y_train)

    prediction = trained_xgb_model.predict(X_train_val)
    
    # guardamos los valores predecidos vs reales en un diccionario
    
    predicciones[i] = {'real' : y_train_val, 'prediccion': prediction}


    pickle.dump(trained_xgb_model, open('models/2_dias/xgboost_2dias_estacion_' + str(i) + '.pkl', 'wb'))

    mean_real = y_train_val.mean()
    mean_prediction = prediction.mean()

    MAPE = mean_absolute_percentage_error(prediction, y_train_val)
    MAE = mean_absolute_error(prediction, y_train_val)
    RMSE = mean_squared_error(prediction, y_train_val, squared = False)
    
    # guardamos las metricas en un diccionario
    
    metricas[i] = {'MAE': MAE, "MAPE": MAPE, 'RMSE': RMSE, 'Media real' : mean_real, 'Media predecida': mean_prediction}
    
    print('ESTACION '+ str(i) + ':')
    print('prediction shape: ', prediction.shape)
    print('test shape: ', y_train_val.shape)
    print('MAE :', MAE)
    print('MAPE: ', MAPE)
    print('RMSE: ', RMSE)
    print('\n')
    print('media real: ', mean_real)
    print('media predecida: ', mean_prediction)
    print('\n')
# Out:
# ESTACION 1:
# prediction shape:  (313, 288)
# test shape:  (313, 288)
# MAE : 9.464846721959105
# MAPE:  0.25605603368540414
# RMSE:  12.269739001264776
#
#
# media real:  38.18857605608804
# media predecida:  39.28557
#
#
# ESTACION 2:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 7.2172486408422
# MAPE:  0.23435295239743395
# RMSE:  10.222800874043818
#
#
# media real:  33.895066596565016
# media predecida:  30.316801
#
#
# ESTACION 3:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 8.77028386996288
# MAPE:  0.19803460895336883
# RMSE:  12.624405665761945
#
#
# media real:  46.159338853838065
# media predecida:  44.25019
#
#
# ESTACION 4:
# prediction shape:  (313, 288)
# test shape:  (313, 288)
# MAE : 8.489593069165956
# MAPE:  0.27614865296890717
# RMSE:  11.701072274420689
#
#
# media real:  34.56862353567625
# media predecida:  32.36008
#
#
# ESTACION 5:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 7.67276519410576
# MAPE:  0.2509387867525026
# RMSE:  11.649002656635153
#
#
# media real:  31.582040834209604
# media predecida:  29.1773
#
#
# ESTACION 6:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 13.728592179791367
# MAPE:  0.271393888566579
# RMSE:  23.066507618099667
#
#
# media real:  54.549476428321064
# media predecida:  46.017914
#
#
# ESTACION 7:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 7.609788959235465
# MAPE:  0.2716068038520707
# RMSE:  12.566042626805505
#
#
# media real:  29.612589817735717
# media predecida:  25.95922
#
#
# ESTACION 8:
# prediction shape:  (317, 288)
# test shape:  (317, 288)
# MAE : 9.840646160378023
# MAPE:  0.248554363890162
# RMSE:  15.660870984281777
#
#
# media real:  42.55343059936909
# media predecida:  37.748985
#
#
# ESTACION 9:
# prediction shape:  (313, 288)
# test shape:  (313, 288)
# MAE : 7.189545396737884
# MAPE:  0.387487850594517
# RMSE:  9.709565381350487
#
#
# media real:  18.623735356762513
# media predecida:  19.758522
#
#
# ESTACION 10:
# prediction shape:  (313, 288)
# test shape:  (313, 288)
# MAE : 7.496818619842726
# MAPE:  0.2729224355909313
# RMSE:  12.432662351454177
#
#
# media real:  27.23738684771033
# media predecida:  26.590195
#
#
# CPU times: total: 3h 45min 54s
# Wall time: 20min 37s

# %%
total = 0

for i in [1,2,3,4,5,6,7,8,10]:
    total = total + metricas[i]['MAPE']

print(total/10)

total = 0

for i in [1,2,3,4,5,6,7,8,10]:
    total = total + metricas[i]['MAE']

print(total/10)
total = 0
    
for i in [1,2,3,4,5,6,7,8,10]:
    total = total + metricas[i]['RMSE']

print(total/10)

total = 0
    
for i in [1,2,3,4,5,6,7,8,10]:
    total = total + metricas[i]['Media real']

print(total/10)

total = 0
    
for i in [1,2,3,4,5,6,7,8,10]:
    total = total + metricas[i]['Media predecida']

print(total/10)
# Out:
# 0.22800085266573594
# 8.029058341528348
# 12.21931040527675
# 33.834652956951324
# 31.170625495910645

# %% [markdown]
# # sin 9
#
# MAPE: 0.22800085266573594
#
# MAE: 8.029058341528348
#
# RMSE: 12.21931040527675
#
# MEDIA REAL: 33.834652956951324
#
# MEDIA PREDECIDA: 31.170625495910645
#
#
# # con 9
#
#
# MAPE: 0.26674963772518767
#
# MAE: 8.748012881202136
#
# RMSE: 13.1902669434118
#
# MEDIA REAL: 35.69702649262757
#
# MEDIA PREDECIDA: 33.146477699279785

# %%
df_metricas = pd.DataFrame.from_dict(metricas)

df_metricas.to_csv('metricas_10estaciones_2dias.csv')

# %%
df_predicciones = pd.DataFrame.from_dict(predicciones)

df_predicciones.to_csv('predicciones_10estaciones_2dias.csv')

# %%
# %%time


# Hiperparametros Optuna parado

# params = {'max_depth': 6, 
#           'learning_rate': 0.010049185067138871, 
#           'n_estimators': 294, 
#           'min_child_weight': 6, 
#           'gamma': 0.0012980577270314173, 
#           'subsample': 0.18828660906502742, 
#           'colsample_bytree': 0.9488588949410688}

#Hiperparametros ejemplo

# params = {'learning_rate' : 0.025,
#           'n_estimators' : 250,
#           'max_depth': 2,
#           'min_child_weight' : 1,
#           'gamma': 0.0,
#           'subsample': 0.98,
#           'colsample_bytree': 0.98,
#           'scale_pos_weight': 0.8,
#           'seed': 42,
#           'verbosity' : 0}


# Hiperparametros optuna completado
# Out:
# prediction (213, 288)
# test (213, 288)
# RMSE:  10.866205543857895
# MAE:  7.2546269617465615
# CPU times: total: 1h 9min 33s
# Wall time: 6min 31s

# %%
# Out:
# 28.150202138758477
# 27.673008
# 0.27459897048248555

# %% [markdown]
# # Valores para parametros de optuna incompleto

# %% [markdown]
# * media real: 28.150202138758477
# * media predecida: 27.714634
#
#
# * RMSE:  10.886802850195714
# * MAE:  7.321197804384202
# * MAPE: 0.2760916690053607
#
# # Valores para parametros de optuna terminado
#
# * 28.150202138758477
# * 27.673008
#
# * RMSE:  10.866205543857895
# * MAE:  7.2546269617465615
# * MAPE: 0.27459897048248555

# %% [markdown]
# # Valores para parametros del paper
#
# * Media real: 28.150202138758477
# * Media predecida: 29.366629
#
# * RMSE:  10.724885901102555
# * MAE:  7.297981035549254
#
# * MAPE: 0.2604501639385927

# %% [markdown]
# # Arreglos para graficar

# %%
pred_1 = []

prediction = predicciones[4]['prediccion']
y_real = predicciones[4]['real']

for i in range(3, len(prediction), 4):
    pred_1.append(prediction[i])
    
pred_1 = np.asarray(pred_1)
    
test_1 = []

for i in range(3, len(y_real), 4):
    test_1.append(y_real[i])
    
test_1 = np.asarray(test_1)

print(pred_1.shape)
print(test_1.shape)
# Out:
# (78, 288)
# (78, 288)

# %%
y_pred = np.reshape(pred_1, ( len(pred_1) * len(pred_1[0])))
y_test_1 = np.reshape(test_1, (len(test_1) * len(test_1[0])))

print(y_pred)
print(y_test_1)

fig_val = go.Figure()

fig_val.add_trace(
    go.Scatter( y = list(y_test_1), name = 'Target'))

fig_val.add_trace(
     go.Scatter( y = list(y_pred), name = 'Forecasts'))

fig_val.update_layout( title_text = "Validation - Forecasts vs Targets")
# Out:
# [27.221348 27.245003 27.333023 ... 53.54071  52.45291  49.872814]
# [29. 29. 29. ... 61. 61. 61.]
# <div>                            <div id="82f51dba-64df-4b74-9583-39dc86d9478f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82f51dba-64df-4b74-9583-39dc86d9478f")) {                    Plotly.newPlot(                        "82f51dba-64df-4b74-9583-39dc86d9478f",                        [{"name":"Target","y":[29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,38.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,33.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,29.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,25.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,21.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,17.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12.0,12 ...
